# %% [markdown]
# <a href="https://colab.research.google.com/github/Marieta3/russian-text-recognition/blob/master/russian-text-recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OCR ruskog teksta

# %% [markdown]
# ### Import

# %%
import numpy as np
import cv2 # OpenCV
import matplotlib
import matplotlib.pyplot as plt
import collections
import tensorflow as tf
from tensorflow import keras
# keras
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD

# k-means
from sklearn.cluster import KMeans

import pytesseract
from googletrans import Translator

# %% [markdown]
# ### Instalacije

# %%
# !pip install h5py pyyaml #already satisfied

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
# !sudo apt-get install tesseract-ocr-[rus]

# %%
# !pip install googletrans

# %% [markdown]
# ### Import repozitorijuma

# %%
# !git clone https://github.com/Marieta3/russian-text-recognition

# %%
# iscrtavanje slika u notebook-u
# %matplotlib inline
# prikaz vecih slika
matplotlib.rcParams['figure.figsize'] = 16,12

# %% [markdown]
# ### Konstante

# %%
IMAGES_PATH = 'russian-text-recognition/images/'
MODELS_PATH = 'russian-text-recognition/models/'
alphabet_upper_case = ["А", "Б", "В", "Г", "Д", "Е", "Ё", "Ж", "З", "И", "Й", "К", "Л", "М", "Н", "О", "П", "Р", "С", "Т", "У", "Ф", "Х", "Ц", "Ч", "Ш", "Щ", "Ъ", "Ы", "Ь", "Э", "Ю", "Я"]
alphabet_lower_case = ["а", "б", "в", "г", "д", "е", "ё", "ж", "з", "и", "й", "к", "л", "м", "н", "о", "п", "р", "с", "т", "у", "ф", "х", "ц", "ч", "ш", "щ", "ъ", "ы", "ь", "э", "ю", "я"]
alphabet = ["А", "Б", "В", "Г", "Д", "Е", "Ё", "Ж", "З", "И", "Й", "К", "Л", "М", "Н", "О", "П", "Р", "С", "Т", "У", "Ф", "Х", "Ц", "Ч", "Ш", "Щ", "Ъ", "Ы", "Ь", "Э", "Ю", "Я", "а", "б", "в", "г", "д", "е", "ё", "ж", "з", "и", "й", "к", "л", "м", "н", "о", "п", "р", "с", "т", "у", "ф", "х", "ц", "ч", "ш", "щ", "ъ", "ы", "ь", "э", "ю", "я"]
alphabet_simple = ["А", "Б", "В", "Г", "Д", "Е", "Ё", "Ж", "З", "И", "Й", "К", "Л", "М", "Н", "О", "П", "Р", "С", "Т", "У", "Ф", "Х", "Ц", "Ч", "Ш", "Щ", "Ъ", "Ы", "Ь", "Э", "Ю", "Я", "а", "б", "е", "ё"]
alphabet_simple1 = ["А", "Б", "в", "г", "д", "Е", "Ё", "ж", "з", "и", "й", "к", "л", "м", "н", "о", "п", "р", "с", "т", "у", "ф", "х", "ц", "ч", "ш", "щ", "ъ", "ы", "ь", "э", "ю", "я", "а", "б", "е", "ё"]

# %% [markdown]
# ### Funkcije za obradu slike

# %%
def load_image(path):
    return cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)

def image_gray(image):
    return cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

def image_bin(image_gs):
    height, width = image_gs.shape[0:2]
    image_binary = np.ndarray((height, width), dtype=np.uint8)
    ret, image_bin = cv2.threshold(image_gs, 127, 255, cv2.THRESH_BINARY)
    return image_bin

def invert(image):
    return 255-image

def display_image(image, color=False):
    if color:
        plt.imshow(image)
    else:
        plt.imshow(image, 'gray')

def dilate(image):
    kernel = np.ones((3, 3)) # strukturni element 3x3 blok
    return cv2.dilate(image, kernel, iterations=1)

def erode(image):
    kernel = np.ones((3, 3)) # strukturni element 3x3 blok
    return cv2.erode(image, kernel, iterations=1)

# %% [markdown]
# ### Izdvajanje regiona od interesa

# %%
def resize_region(region):
    return cv2.resize(region, (28, 28), interpolation=cv2.INTER_NEAREST)

# %%
def select_roi(image_orig, image_bin):
    contours, hierarchy = cv2.findContours(image_bin.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    sorted_regions = [] # lista sortiranih regiona po X osi
    regions_array = []
    regions_array_orig = []
    #contours1 = remove_inner_rois(contours)
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour) # koordinate i velicina granicnog pravougaonika
        area = cv2.contourArea(contour)
        #zasto 100? 30*42 sa malim greskama
        if area > 50 and h < 100 and h > 15 and w > 15:
            # kopirati [y:y+h+1, x:x+w+1] sa binarne slike i smestiti u novu sliku
            # oznaciti region pravougaonikom na originalnoj slici sa rectangle funkcijom
            if not is_inner(x, y, w, h, contours, image_bin.shape): #izbacujemo unutrasnje konture, npr ako imam slovo O
              region = image_bin[y:y+h+1, x:x+w+1]
              regions_array.append([resize_region(region), (x, y, w, h)])

              image_orig_gray = image_gray(image_orig)
              region_orig = image_orig[y:y+h+1, x:x+w+1]
              regions_array_orig.append([region_orig, (x, y, w, h)])
              cv2.rectangle(image_orig, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    regions_array = sorted(regions_array, key=lambda x: x[1][0])
    sorted_regions = [region[0] for region in regions_array]

    #regions_array_orig = sorted(regions_array_orig, key=lambda x: x[1][1])
    #sorted_regions_orig = [region[0] for region in regions_array_orig]
    return image_orig, sorted_regions, regions_array_orig

# %%
def is_inner(x2, y2, w2, h2, contours, shape):
  h, w = shape
  for c in contours:
    x1, y1, w1, h1 = cv2.boundingRect(c)
    if not x1 == 0 and not y1 == 0 and not h1 == h and not w1 == w and x1 < x2 < (x2 + w2) < (x1 + w1) and y1 < y2 < (y2 + h2) < (y1 + h1):
      return True
  return False

# %%
def remove_inner_rois(contours):
  retVal = []
  to_remove = []
  temp = contours
  
  for i in range (len(contours)):
    x1, y1, w1, h1 = cv2.boundingRect(contours[i])
    for j in range (len(contours)):
      x2, y2, w2, h2 = cv2.boundingRect(contours[j])
      if x1 < x2 < (x2 + w2) < (x1 + w1) and y1 < y2 < (y2 + h2) < (y1 + h1):
        to_remove.append(contours[j])
      else:
        #if np.any(contours[j] not in retVal):
          retVal.append(contours[j])
  print(len(retVal))
  for item in to_remove:
    temp.remove(item)
  print(len(temp))   
  return temp

# %%
def sort_regions(regions):
  #sort po y osi
  regions = sorted(regions, key=lambda x: x[1][1])
  new_lines = [0]
  for i in range (len(regions)-1):
    r1 = regions[i]
    r2 = regions[i+1]
    #provera da li su u istom redu
    if abs(r2[1][1]-r1[1][1]) > r1[1][3]:
      #nisu u istom redu
      new_lines.append(i+1)
    new_lines.append(len(regions))

  #sort po x osi u svakom redu
  for i in range (len(new_lines)-1):
    regions[new_lines[i]:new_lines[i+1]] = sorted(regions[new_lines[i]:new_lines[i+1]], key=lambda x: x[1][0])

  return regions

# %% [markdown]
# ### Priprema podataka za obučavanje

# %%
def scale_to_range(image):
    return image/255

# %%
def matrix_to_vector(image):
    return image.flatten()

# %%
# test za proveru
test_scale_matrix = np.array([[0, 255], [51, 153]], dtype='float')
test_scale_ref = np.array([[0., 1.], [0.2, 0.6]], dtype='float')
test_scale_res = scale_to_range(test_scale_matrix)
print("Test scale passed: ", np.array_equal(test_scale_res, test_scale_ref))

test_mtv = np.ndarray((28, 28))
test_mtv_ref = (784, )
test_mtv_res = matrix_to_vector(test_mtv).shape
print("Test matrix to vector passed: ", test_mtv_res == test_mtv_ref)
# Out:
# Test scale passed:  True
# Test matrix to vector passed:  True

# %%
def prepare_for_ann(regions):
    ready_for_ann = []
    for region in regions:
        scale = scale_to_range(region)
        ready_for_ann.append(matrix_to_vector(scale))
    return ready_for_ann
#vraca pobudjenost za svaki neuron od 0 do 1

# %%
def convert_output(alphabet):
    nn_outputs = []
    for index in range(len(alphabet)):
        output = np.zeros(len(alphabet))
        output[index] = 1
        nn_outputs.append(output)
    return np.array(nn_outputs)

# %% [markdown]
# ### Neuronska mreža

# %%
def create_ann(output_size):
    ann = Sequential()
    ann.add(Dense(128, input_dim=784, activation='sigmoid'))
    ann.add(Dense(output_size, activation='sigmoid'))
    return ann

# %%
def train_ann(ann, X_train, y_train, epochs):
    X_train = np.array(X_train, np.float32) # dati ulaz
    y_train = np.array(y_train, np.float32) # zeljeni izlazi na date ulaze
    
    print("\nTraining started...")
    sgd = SGD(lr=0.01, momentum=0.9)
    ann.compile(loss='mean_squared_error', optimizer=sgd)
    ann.fit(X_train, y_train, epochs=epochs, batch_size=1, verbose=0, shuffle=False)
    print("\nTraining completed...")
    return ann

# %% [markdown]
# ### Funkcije za predprocesiranje

# %%
def training_preprocess(img, repeat_erode = 1):
  alf_gray = image_gray(img)
  alf_bin = image_bin(alf_gray)
  for i in range (repeat_erode):
    alf_bin = erode(alf_bin)
  return alf_bin

# %% [markdown]
# ### Funkcije za obučavanje

# %%
def train(ann, img_path, alphabet, display = False, epochs = 1000):
  alf_img = load_image(img_path)
  alf_bin = training_preprocess(img=alf_img, repeat_erode=3)
  if display:
    display_image(alf_img)
    display_image(alf_bin)
  selected_regions_alf, letters_alf, letters_alf_orig = select_roi(alf_img.copy(), alf_bin)
  display_image(selected_regions_alf)

  inputs =prepare_for_ann(letters_alf)
  outputs = convert_output(alphabet)
  #ann = create_ann(output_size=len(alphabet))
  ann = train_ann(ann, inputs, outputs, epochs)

  result = ann.predict(np.array(inputs, np.float32))
  print("result")
  print("\n")
  print(display_result(result, alphabet))
  return ann

# %% [markdown]
# ### Čuvanje modela

# %%
def save_model(model, path):
  model_json = model.to_json()
  with open(path, "w") as json_file:
    json_file.write(model_json)
  model.save_weights("model.h5")
def save_model1(model, path):
  model.save(path)

def load_model1(path):
  new_model = keras.models.load_model(path)
  new_model.summary()
  return new_model
  
def load_model(path):
  json_file = open(path, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  loaded_model = model_from_json(loaded_model_json)
  loaded_model.load_weights("model.h5")

# %% [markdown]
# ### Određivanje pobedničkog neurona

# %%
def winner(output):
    return max(enumerate(output), key=lambda x: x[1])[0]

# %% [markdown]
# ### Prikaz rezultata

# %%
def display_result(outputs, alphabet):
    result = []
    for output in outputs:
        result.append(alphabet[winner(output)])
    return result

# %%
def display_result_with_spaces(outputs, alphabet, k_means):
    # odredjivanje indeksa grupe koja odgovara rastojanju izmedju reci
    w_space_group = max(enumerate(k_means.cluster_centers_), key=lambda x: x[1])[0]
    result = alphabet[winner(outputs[0])]
    # iterativno dodavanje prepoznatih elemenata
    # dodavanje space karaktera ako je rastojanje izmedju dva slova odgovara rastojanju izmedju reci
    for idx, output in enumerate(outputs[1:, :]):
        if k_means.labels_[idx] == w_space_group:
            result += ' '
        result += alphabet[winner(output)]
    return result

# %% [markdown]
# ### Kreiranje NN i treniranje

# %%
def createNN_and_train(alph, alph_path):
  ann = create_ann(output_size=len(alph))
  #ann = train(ann, img_path='upper_case.png', alphabet=alphabet_upper_case, display=True)
  #ann = train(ann, img_path='lower_case.png', alphabet=alphabet_lower_case, display=True)
  ann = train(ann, img_path=alph_path, alphabet=alph, display=True, epochs = 2000)
  save_model(ann, 'model.json')
  return ann

# %%
ann = createNN_and_train(alphabet_simple1, IMAGES_PATH + 'alphabet_simple.png')
# Out:
# Training started...
#
# Training completed...
# result
#
#
# ['А', 'Б', 'в', 'г', 'д', 'Е', 'Ё', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я', 'а', 'б', 'е', 'ё']

# %%
loaded_ann1 = load_model1(MODELS_PATH + 'model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_4 (Dense)              (None, 37)                4773
# ...
# Total params: 105,253
# Trainable params: 105,253
# Non-trainable params: 0
# _________________________________________________________________

# %%
save_model1(ann, 'model1.h5')

# %%
loaded_ann = load_model1('model1.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_4 (Dense)              (None, 37)                4773
# ...
# Total params: 105,253
# Trainable params: 105,253
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Testiranje

# %%
img = load_image('text5.png')
#img_inv = invert(img)
img_bin = training_preprocess(img=img, repeat_erode=3)
display_image(img_bin)

# %%
selected_regions, letters_alf, letters_alf_orig = select_roi(img.copy(), img_bin)
sorted_orig = sort_regions(letters_alf_orig)
display_image(selected_regions)

# %%
display_image(sorted_orig[-2][0])

# %%
word = letters_alf_orig[6][0]
#word = cv2.resize(word, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
word = cv2.resize(word, None, fx=2, fy=2, interpolation=cv2.INTER_LINEAR)
word_gray = image_gray(word)
word_bin = image_bin(word_gray)

word_bin = erode(word_bin)

#word_bin = dilate(word_bin)
#word_bin = erode(word_bin)
#word_bin = training_preprocess(img=word, repeat_erode = 0)
selected_regions1, letters_alf1, letters_alf_orig1 = select_roi(word.copy(), word_bin)

# %%
display_image(word_bin)

# %%
display_image(letters_alf_orig1[0][0])

# %% [markdown]
# ### Procesiranje slike - funkcije

# %%
def process_image(img_path, images=True):
  if images:
    img_orig = load_image(IMAGES_PATH + img_path)
  else:
    img_orig = load_image(img_path)
  img_bin = training_preprocess(img=img_orig, repeat_erode=3)
  selected_regions, rois, rois_orig = select_roi(img_orig.copy(), img_bin)
  display_image(selected_regions)
  sorted_regions = sort_regions(rois_orig)
  sentence = ""
  for word in sorted_regions:
    word = cv2.resize(word[0], None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
    word_gray = image_gray(word)
    word_bin = image_bin(word_gray)
    word_bin = erode(word_bin)
    #izvlacenje slova iz reci:
    selected_regions1, rois1, rois_orig1 = select_roi(word.copy(), word_bin)
    #sorted_rois1 = sorted(rois1, key = lambda x: x[1][0])
    inputs = prepare_for_ann(rois1[1:])
    result = loaded_ann1.predict(np.array(inputs, np.float32))
    res = ''.join(display_result(result, alphabet_simple1))
    sentence += res
    sentence += ' ' 
  return sentence

# %%
def process_image_without_words(img_path, images=True):
  if images:
    img_orig = load_image(IMAGES_PATH + img_path)
  else:
    img_orig = load_image(img_path)
  img_bin = cv2.resize(img_orig, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
  img_bin = training_preprocess(img=img_orig, repeat_erode=1)
  
  selected_regions, rois, rois_orig = select_roi(img_orig.copy(), img_bin)
  display_image(selected_regions)
  sorted_regions = sort_regions(rois_orig)
  display_image(sorted_regions[-1][0])
  inputs = prepare_for_ann(rois)
  result = loaded_ann1.predict(np.array(inputs, np.float32))
  sentence = ""
  res = ''.join(display_result(result, alphabet_simple1))
  sentence += res
  sentence += ' '
  return sentence

# %%
process_image_without_words('glumac.png', False)

# %%
def process_image_tesseract(img_path):
    img = load_image(img_path)
    text = pytesseract.image_to_string(img, lang='rus')
    return text

# %%
def translate(text, src="ru", dest="sr"):
    translator = Translator()
    result = translator.translate(text, src=src, dest=dest)
    return result.text

# %%
tess_text = process_image_tesseract('glumac.png')
print(tess_text)
# Out:
# актёр был
# хороший

# %%
translated = translate(tess_text)
print(translated)
# Out:
# глумац је
# добро

# %%
text = process_image('text5.png', False)
print(text)
# Out:
# юзэнр стситз бАххфсэ бэйххжеёзр фхйдфлуршэ фдэсжхэихзр бэхзэАяъгъб б Б яэйххэзр сфхвффтАз фф итз зэмэ хёбъшихзр бэфэь щиэзфжт ххйххюффл бэх шф Ажнл шэ сАлмэмэ хдйфх Аяфэлмэсрффйф мэзэхлъ Арнл дсэхэф хдйфхр нлстз х фэьшэ лэфэфз Ахнэз ежмсястзр шАшэ д штф хдзихсязр бэйххх чбф стсёъз х мстзэ хйэдзэ х фттбтбхтшшэ хдффхэх йхютдзит фдбэсрхэхтзр юзэ шэфзф зтйби лэзэ л зтйдзр Арншрь сфхэффэАэ штдфэсрйэ сфар ф етаёзр йхАзфшэй йёАзфшйф нр шэз хдйфе хуфевзр юзэ йэй нра ьэ
